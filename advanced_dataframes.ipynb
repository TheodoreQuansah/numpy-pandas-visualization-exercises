# %% [markdown]
# # Exerxises 1

# %% [markdown]
# 3) Create a function named get_db_url.
#
# It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
import pandas as pd
from sqlalchemy import text, create_engine
import numpy as np
from env import get_connection
from pydataset import data

# %% [markdown]
# 4) Use your function to obtain a connection to the employees database.

# %%
url = get_connection('employees')

# %%
engine =  create_engine(url)

# %% [markdown]
# 5) Once you have successfully run a query:

# %%
query = '''
        SELECT *
        FROM employees
        '''

# %%
text_query = text(query)

# %%
df = pd.read_sql(text(query), engine.connect())
df.head(10)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10001  1953-09-02     Georgi    Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel     Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto    Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 5   10006  1953-04-20     Anneke    Preusig      F  1989-06-02
# 6   10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 7   10008  1958-02-19     Saniya   Kalloufi      M  1994-09-15
# 8   10009  1952-04-19     Sumant       Peac      F  1985-02-18
# 9   10010  1963-06-01  Duangkaew   Piveteau      F  1989-08-24

# %% [markdown]
# # A.
# Intentionally make a typo in the database url. What kind of error message do you see?

# %% [markdown]
# OperationalError: (pymysql.err.OperationalError) (1044, "Access denied for user 'somerville_2278'@'%%' to database 'emploees'")
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# # B.
# Intentionally make an error in your SQL query. What does the error message look like?

# %% [markdown]
# ProgrammingError: (pymysql.err.ProgrammingError) (1146, "Table 'employees.emploees' doesn't exist")
#
# [SQL:
#         Select *
#         From emploees
#         ]
#
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %% [markdown]
# 6) Read the employees and titles tables into two separate DataFrames.

# %%
query = '''
        SELECT *
        FROM employees
        '''

# %%
employees_df = pd.read_sql(text_query, engine.connect())
employees_df.head(10)
# Out:
#    emp_no  birth_date first_name  last_name gender   hire_date
# 0   10001  1953-09-02     Georgi    Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel     Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto    Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian    Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi   Maliniak      M  1989-09-12
# 5   10006  1953-04-20     Anneke    Preusig      F  1989-06-02
# 6   10007  1957-05-23    Tzvetan  Zielinski      F  1989-02-10
# 7   10008  1958-02-19     Saniya   Kalloufi      M  1994-09-15
# 8   10009  1952-04-19     Sumant       Peac      F  1985-02-18
# 9   10010  1963-06-01  Duangkaew   Piveteau      F  1989-08-24

# %%
query = '''
        SELECT *
        FROM titles
        '''

# %%
titles_df = pd.read_sql(text(query), engine.connect())
titles_df
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %% [markdown]
# 7) How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
#employees
employees_df.shape
# Out:
# (300024, 6)

# %%
#titles
titles_df.shape
# Out:
# (443308, 4)

# %% [markdown]
# 8) Display the summary statistics for each DataFrame.

# %%
#employees
employees_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300024 entries, 0 to 300023
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      300024 non-null  int64
#  1   birth_date  300024 non-null  object
#  2   first_name  300024 non-null  object
#  3   last_name   300024 non-null  object
#  4   gender      300024 non-null  object
#  5   hire_date   300024 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 13.7+ MB

# %%
#titles
titles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   emp_no     443308 non-null  int64
#  1   title      443308 non-null  object
#  2   from_date  443308 non-null  object
#  3   to_date    443308 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 13.5+ MB

# %% [markdown]
# 9) How many unique titles are in the titles DataFrame?

# %%
titles_df.title.unique()
# Out:
# array(['Senior Engineer', 'Staff', 'Engineer', 'Senior Staff',
#        'Assistant Engineer', 'Technique Leader', 'Manager'], dtype=object)

# %% [markdown]
# 10) What is the oldest date in the to_date column?

# %%
titles_df.to_date.max()
# Out:
# datetime.date(9999, 1, 1)

# %% [markdown]
# 11) What is the most recent date in the to_date column?

# %%
titles_df.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %% [markdown]
# # Exercises II

# %% [markdown]
# 1) Copy the users and roles DataFrames from the examples above.

# %%
employees_df
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles_df
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %% [markdown]
# 2) What is the result of using a right join on the DataFrames?

# %%
employees_df.merge(titles_df, how = 'right', left_on = 'emp_no', right_on = 'emp_no')
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# 2       Senior Engineer  1995-12-03  9999-01-01
# 3              Engineer  1986-12-01  1995-12-01
# 4       Senior Engineer  1995-12-01  9999-01-01
# ...                 ...         ...         ...
# 443303         Engineer  1987-08-30  1992-08-29
# 443304  Senior Engineer  1992-08-29  9999-01-01
# 443305     Senior Staff  1998-12-27  9999-01-01
# 443306            Staff  1993-12-27  1998-12-27
# 443307         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 9 columns]

# %% [markdown]
# 3) What is the result of using an outer join on the DataFrames?

# %%
employees_df.merge(titles_df, how = 'outer', left_on = 'emp_no', right_on = 'emp_no')
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# 2       Senior Engineer  1995-12-03  9999-01-01
# 3              Engineer  1986-12-01  1995-12-01
# 4       Senior Engineer  1995-12-01  9999-01-01
# ...                 ...         ...         ...
# 443303         Engineer  1987-08-30  1992-08-29
# 443304  Senior Engineer  1992-08-29  9999-01-01
# 443305     Senior Staff  1998-12-27  9999-01-01
# 443306            Staff  1993-12-27  1998-12-27
# 443307         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 9 columns]

# %% [markdown]
# 4) What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
titles_df.drop(columns = ['emp_no'])
employees_df.drop(columns = ['emp_no']).merge(titles_df, how = 'outer', left_on = 'hire_date', right_on = 'from_date')
# Out:
#           birth_date first_name last_name gender   hire_date  emp_no  \
# 0         1953-09-02     Georgi   Facello      M  1986-06-26   10001
# 1         1953-09-02     Georgi   Facello      M  1986-06-26   27425
# 2         1953-09-02     Georgi   Facello      M  1986-06-26   29250
# 3         1953-09-02     Georgi   Facello      M  1986-06-26   35565
# 4         1953-09-02     Georgi   Facello      M  1986-06-26   50733
# ...              ...        ...       ...    ...         ...     ...
# 19950858         NaN        NaN       NaN    NaN         NaN  479976
# 19950859         NaN        NaN       NaN    NaN         NaN  481162
# 19950860         NaN        NaN       NaN    NaN         NaN  487052
# 19950861         NaN        NaN       NaN    NaN         NaN  496696
# 19950862         NaN        NaN       NaN    NaN         NaN  496860
#
#                     title   from_date     to_date
# 0         Senior Engineer  1986-06-26  9999-01-01
# 1                Engineer  1986-06-26  1994-01-28
# 2                   Staff  1986-06-26  1995-06-26
# 3                   Staff  1986-06-26  1995-06-26
# 4                Engineer  1986-06-26  1994-11-16
# ...                   ...         ...         ...
# 19950858  Senior Engineer  2001-05-27  9999-01-01
# 19950859  Senior Engineer  2001-05-27  9999-01-01
# 19950860     Senior Staff  2001-05-27  9999-01-01
# 19950861     Senior Staff  2001-05-27  9999-01-01
# 19950862     Senior Staff  2001-05-27  9999-01-01
#
# [19950863 rows x 9 columns]

# %% [markdown]
# 5) Load the mpg dataset from PyDataset.

# %%
mpg = data('mpg')

# %% [markdown]
# 6) Output and read the documentation for the mpg dataset.

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %% [markdown]
# 7) How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# 8) Check out your column names and perform any cleanup you may want on them.

# %%
mpg.columns
# Out:
# Index(['manufacturer', 'model', 'displ', 'year', 'cyl', 'trans', 'drv', 'cty',
#        'hwy', 'fl', 'class'],
#       dtype='object')

# %% [markdown]
# 9) Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# 10) How many different manufacturers are there?

# %%
mpg.manufacturer.nunique()
# Out:
# 15

# %% [markdown]
# 11) How many different models are there?

# %%
mpg.model.nunique()
# Out:
# 38

# %% [markdown]
# 12) Create a column named mileage_difference like you did in the DataFrames exercises;
#
# this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.hwy - mpg.cty
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference
# 1    compact                  11
# 2    compact                   8
# 3    compact                  11
# 4    compact                   9
# 5    compact                  10
# ..       ...                 ...
# 230  midsize                   9
# 231  midsize                   8
# 232  midsize                  10
# 233  midsize                   8
# 234  midsize                   9
#
# [234 rows x 12 columns]

# %% [markdown]
# 13) Create a column named average_mileage like you did in the DataFrames exercises;
#
# this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.hwy + mpg.cty)/2
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage
# 1    compact                  11             23.5
# 2    compact                   8             25.0
# 3    compact                  11             25.5
# 4    compact                   9             25.5
# 5    compact                  10             21.0
# ..       ...                 ...              ...
# 230  midsize                   9             23.5
# 231  midsize                   8             25.0
# 232  midsize                  10             21.0
# 233  midsize                   8             22.0
# 234  midsize                   9             21.5
#
# [234 rows x 13 columns]

# %% [markdown]
# 14) Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg['is_automatic'] = mpg.trans.str.contains('auto', case=False )
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  mileage_difference  average_mileage  is_automatic
# 1    compact                  11             23.5          True
# 2    compact                   8             25.0         False
# 3    compact                  11             25.5         False
# 4    compact                   9             25.5          True
# 5    compact                  10             21.0          True
# ..       ...                 ...              ...           ...
# 230  midsize                   9             23.5          True
# 231  midsize                   8             25.0         False
# 232  midsize                  10             21.0          True
# 233  midsize                   8             22.0         False
# 234  midsize                   9             21.5          True
#
# [234 rows x 14 columns]

# %% [markdown]
# 15) Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
round(mpg.groupby('manufacturer').average_mileage.agg('mean')).sort_values().tail(1)
# Out:
# manufacturer
# honda    28.0
# Name: average_mileage, dtype: float64

# %% [markdown]
# 16) Do automatic or manual cars have better miles per gallon?

# %%
#The mean of the of every auto transmission
avg_auto_mileage = round(mpg.loc[mpg['auto_or_man'] == 'auto', 'average_mileage'].mean())

# %%
#The mean of the of every manual transmission
avg_man_mileage = round(mpg.loc[mpg['auto_or_man'] == 'manual', 'average_mileage'].mean())

# %%
#Manual cars have better miles per gallon than automatic cars
avg_man_mileage > avg_auto_mileage
# Out:
# True
